# %%
import matplotlib.pyplot as pl
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
import pandas as pd
pd.options.display.max_colwidth = 200

# %%
pl.rcParams['figure.figsize'] = 20,7
pl.rcParams['font.family'] = 'sans-serif'
pl.rcParams['font.sans-serif'] = ['DejaVu Sans']

# %%
from pycoQC.pycoQC import pycoQC

# %%
from pycoQC.pycoQC_fun import jhelp, jprint

# %%
p_2aug = pycoQC("/nas6/lcho/nanopore/wgs_hkcgs_demo_DMD_2aug/basecalled/seq_summary_all.txt", verbose = True)
# Out:
# <p><b>Importing data</b></p>
# <p>&emsp;1637457 reads found in initial file</p>
# <p><b>Verify and rearrange fields</b></p>
# <p>&emsp;1D Run type</p>
# <p><b>Order run IDs by start time</b></p>
# <p>&emsp;Processing reads with Run_ID 0f90dd3541923d4a0a359381ec7a0b9e5406d467</p>
# <p>&emsp;Processing reads with Run_ID 656b1111a481d710b7cbab8ec5edbca5741dd330</p>
# <p><b>Reindex and sort</b></p>
# <p>&emsp;1637457 Total valid reads found</p>

# %%
g_2aug = p_2aug.overview(cmap='Set3', plot_style='ggplot')
# Out:
# <p><b>Overall counts</b></p>
#                          Count
# Reads             1.637457e+06
# Bases             1.486526e+10
# Events            3.473816e+10
# Active Channels   4.960000e+02
# Run Duration (h)  8.778237e+01
# <p><b><br>Read count per Run ID</b></p>
#                                             reads
# 656b1111a481d710b7cbab8ec5edbca5741dd330  1635990
# 0f90dd3541923d4a0a359381ec7a0b9e5406d467     1467
# <p><b><br>Distribution of quality scores and read lengths</b></p>
#        Quality score distribution  Read length distribution
# count                1.637457e+06              1.637457e+06
# mean                 9.548174e+00              9.078260e+03
# std                  2.098380e+00              7.598825e+03
# min                  0.000000e+00              0.000000e+00
# 10%                  6.150000e+00              1.235000e+03
# 25%                  8.901000e+00              2.628000e+03
# 50%                  1.028400e+01              7.907000e+03
# ...

# %%
g = p_2aug.output_over_time(level='bases', figsize=[12,4], binsize=240, bin_smoothing=5)

# %%
g= p_2aug.output_over_time(level='bases', figsize=[12,4], bin_size=200, bin_smothing=1, cumulative=True)

# %%
b = p_2aug.channels_activity(level='reads', figsize=[12,6])
