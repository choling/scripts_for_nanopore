# %%
import matplotlib.pyplot as pl
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
import pandas as pd
pd.options.display.max_colwidth = 200

# %%
pl.rcParams['figure.figsize'] = 20,7
pl.rcParams['font.family'] = 'sans-serif'
pl.rcParams['font.sans-serif'] = ['DejaVu Sans']

# %%
from pycoQC.pycoQC import pycoQC

# %%
from pycoQC.pycoQC_fun import jhelp, jprint

# %%
p_29mar = pycoQC("/nas6/lcho/nanopore/wgs_hkcgs_dh2_29mar/basecalled/sequencing_summary.txt", verbose=True)
# Out:
# <p><b>Importing data</b></p>
# <p>&emsp;1695966 reads found in initial file</p>
# <p><b>Verify and rearrange fields</b></p>
# <p>&emsp;1D Run type</p>
# <p><b>Order run IDs by start time</b></p>
# <p>&emsp;Processing reads with Run_ID ed70710b131a3a899183271db096396be7f31aa3</p>
# <p><b>Reindex and sort</b></p>
# <p>&emsp;1695966 Total valid reads found</p>

# %%
g_29mar = p_29mar.overview(cmap='Set3', plot_style='ggplot')
# Out:
# <p><b>Overall counts</b></p>
#                          Count
# Reads             1.695966e+06
# Bases             9.740229e+09
# Events            2.131895e+10
# Active Channels   4.840000e+02
# Run Duration (h)  4.799736e+01
# <p><b><br>Read count per Run ID</b></p>
#                                             reads
# ed70710b131a3a899183271db096396be7f31aa3  1695966
# <p><b><br>Distribution of quality scores and read lengths</b></p>
#        Quality score distribution  Read length distribution
# count                1.695966e+06              1.695966e+06
# mean                 9.131324e+00              5.743175e+03
# std                  1.666183e+00              3.988918e+03
# min                  0.000000e+00              0.000000e+00
# 10%                  6.643000e+00              1.381000e+03
# 25%                  8.305000e+00              2.495000e+03
# 50%                  9.503000e+00              4.955000e+03
# ...

# %%
g = p_29mar.output_over_time(level='bases', figsize=[12,4], binsize=240, bin_smoothing=5)

# %%
g = p_29mar.output_over_time(level='bases', figsize=[12,4], binsize=240, bin_smoothing=5, cumulative=True)

# %%
a= p_29mar.channels_activity(level='reads', figsize=[12,6])

# %%
l = p_29mar.channels_activity(level='events', cmap="viridis_r", cbar=True, annot=False, figsize=[12,6])
